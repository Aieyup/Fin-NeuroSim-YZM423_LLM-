# %%
"""
Google Colab Kurulum Scripti.

Bu script, Fin-NeuroSim 2.0 projesini Google Colab ortamında
çalıştırmak için gerekli tüm kurulumları yapar.
"""

import os
import sys
import subprocess
from pathlib import Path


def install_dependencies():
    """
    Gerekli Python paketlerini yükler.
    """
    print("📦 Bağımlılıklar yükleniyor...")

    packages = [
        "transformers>=4.35.0",
        "torch>=2.0.0",
        "bitsandbytes>=0.41.0",
        "accelerate>=0.24.0",
        "sentence-transformers>=2.2.0",
        "scikit-learn>=1.3.0",
        "numpy>=1.24.0",
        "httpx>=0.25.0",
        "aiohttp>=3.9.0",
        "requests>=2.31.0",
        "pydantic>=2.5.0",
        "pydantic-settings>=2.1.0",
        "python-dotenv>=1.0.0",
        "alpha-vantage>=2.3.1",
        "fredapi>=0.5.1",
        "tavily-python>=0.3.0",
        "python-dateutil>=2.8.2",
        "nest-asyncio>=1.5.0",
    ]

    for package in packages:
        try:
            subprocess.check_call(
                [sys.executable, "-m", "pip", "install", package, "-q"],
                stdout=subprocess.DEVNULL
            )
        except subprocess.CalledProcessError as e:
            print(f"⚠️  {package} yüklenemedi: {e}")

    print("✅ Bağımlılıklar yüklendi")


def setup_colab_environment(base_path: str):
    """
    Colab ortamını yapılandırır.

    Args:
        base_path: Proje base path'i.
    """
    print(f"🔧 Colab ortamı yapılandırılıyor: {base_path}")

    # Path'i sys.path'e ekle
    if base_path not in sys.path:
        sys.path.insert(0, base_path)
        print(f"✅ Path eklendi: {base_path}")

    # __init__.py dosyalarını kontrol et ve oluştur
    init_files = [
        f"{base_path}/__init__.py",
        f"{base_path}/core/__init__.py",
        f"{base_path}/llm/__init__.py",
        f"{base_path}/agents/__init__.py",
        f"{base_path}/data_sources/__init__.py",
        f"{base_path}/prompts/__init__.py",
        f"{base_path}/schemas/__init__.py",
        f"{base_path}/utils/__init__.py",
        f"{base_path}/mvp/__init__.py",
    ]

    for init_file in init_files:
        path = Path(init_file)
        if not path.exists():
            path.parent.mkdir(parents=True, exist_ok=True)
            path.write_text('"""Package init file."""\n', encoding='utf-8')
            print(f"✅ Oluşturuldu: {init_file}")

    print("✅ Colab ortamı yapılandırıldı")


def check_cuda():
    """
    CUDA durumunu kontrol eder.
    """
    import torch

    print("\n🔍 CUDA Durumu:")
    print(f"  CUDA Mevcut: {torch.cuda.is_available()}")

    if torch.cuda.is_available():
        print(f"  CUDA Versiyonu: {torch.version.cuda}")
        print(f"  GPU Adı: {torch.cuda.get_device_name(0)}")
        print(f"  GPU Sayısı: {torch.cuda.device_count()}")
        print(f"  VRAM: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.2f} GB")
    else:
        print("  ⚠️  CUDA bulunamadı! GPU kullanılamayacak.")


if __name__ == "__main__":
    base_path = "/content/drive/MyDrive/LLM_Proje/fin_neurosim"

    print("🚀 Fin-NeuroSim 2.0 Colab Kurulumu Başlatılıyor...\n")

    # Bağımlılıkları yükle
    install_dependencies()

    # Ortamı yapılandır
    setup_colab_environment(base_path)

    # CUDA kontrolü
    check_cuda()

    print("\n✅ Kurulum tamamlandı!")
# Out:
# 🚀 Fin-NeuroSim 2.0 Colab Kurulumu Başlatılıyor...
#
# 📦 Bağımlılıklar yükleniyor...
# ✅ Bağımlılıklar yüklendi
# 🔧 Colab ortamı yapılandırılıyor: /content/drive/MyDrive/LLM_Proje/fin_neurosim
# ✅ Path eklendi: /content/drive/MyDrive/LLM_Proje/fin_neurosim
# ✅ Colab ortamı yapılandırıldı
#
# 🔍 CUDA Durumu:
#   CUDA Mevcut: True
#   CUDA Versiyonu: 12.6
#   GPU Adı: Tesla T4
#   GPU Sayısı: 1
#   VRAM: 14.74 GB
#
# ✅ Kurulum tamamlandı!

# %%
"""
Google Colab Hızlı Başlangıç Scripti.

Bu script, Colab ortamında projeyi hızlıca çalıştırmak için
tüm gerekli adımları içerir.
"""

import asyncio
import os
import sys
import nest_asyncio
from pathlib import Path

# Colab'da async için gerekli
nest_asyncio.apply()

# CUDA kontrolü
import torch
print(f"CUDA Mevcut: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"VRAM: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.2f} GB")

# Google Drive bağla
from google.colab import drive
drive.mount('/content/drive')

# HuggingFace token
from huggingface_hub import login
hf_token = os.getenv('HF_TOKEN', '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')
os.environ['HF_TOKEN'] = hf_token
login(token=hf_token)

# API anahtarları
os.environ['TAVILY_API_KEY'] = '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'
os.environ['ALPHA_VANTAGE_API_KEY'] = '07UMDN5IJPJ5655A'  # Kendi anahtarınızı ekleyin
os.environ['FRED_API_KEY'] = '94daa0e70904418ba8928c45718e4e5f'  # Kendi anahtarınızı ekleyin

# Proje path'i
base_path = '/content/drive/MyDrive/LLM_Proje/fin_neurosim'

# Önce proje yapısını kontrol et
print("🔍 Proje yapısı kontrol ediliyor...")
from pathlib import Path
base_path_obj = Path(base_path)

if not base_path_obj.exists():
    print(f"\n❌ Proje klasörü bulunamadı: {base_path}")
    print("\n📋 Yapmanız gerekenler:")
    print("1. Tüm 'fin_neurosim' klasörünü Google Drive'a yükleyin")
    print(f"2. Hedef konum: {base_path}")
    print("\n💡 İpucu: Proje dosyalarını zip olarak yükleyip açabilirsiniz:")
    print("   !unzip /content/drive/MyDrive/LLM_Proje/fin_neurosim.zip -d /content/drive/MyDrive/LLM_Proje/")
    raise FileNotFoundError(f"Proje klasörü bulunamadı: {base_path}")

# Klasörleri oluştur
folders = [
    "core", "llm", "agents", "data_sources",
    "prompts", "schemas", "utils", "mvp"
]

for folder in folders:
    folder_path = Path(base_path) / folder
    folder_path.mkdir(parents=True, exist_ok=True)
    print(f"✅ {folder_path}")

# __init__.py dosyalarını oluştur
init_files = [
    f"{base_path}/__init__.py",
    f"{base_path}/core/__init__.py",
    f"{base_path}/llm/__init__.py",
    f"{base_path}/agents/__init__.py",
    f"{base_path}/data_sources/__init__.py",
    f"{base_path}/prompts/__init__.py",
    f"{base_path}/schemas/__init__.py",
    f"{base_path}/utils/__init__.py",
    f"{base_path}/mvp/__init__.py",
]

for init_file in init_files:
    path = Path(init_file)
    if not path.exists():
        path.parent.mkdir(parents=True, exist_ok=True)
        path.write_text('"""Package init file."""\n', encoding='utf-8')
        print(f"✅ Oluşturuldu: {init_file}")

# Proje dosyalarının varlığını kontrol et
base_path_obj = Path(base_path)
if not base_path_obj.exists():
    print(f"❌ Proje klasörü bulunamadı: {base_path}")
    print("\n📋 Proje dosyalarını yüklemek için:")
    print("1. Tüm 'fin_neurosim' klasörünü Google Drive'a yükleyin")
    print(f"2. Hedef konum: {base_path}")
    print("\nAlternatif: Proje dosyalarını zip olarak yükleyip açabilirsiniz:")
    print("  !unzip /content/drive/MyDrive/LLM_Proje/fin_neurosim.zip -d /content/drive/MyDrive/LLM_Proje/")
    raise FileNotFoundError(f"Proje klasörü bulunamadı: {base_path}")

# Kritik dosyaların varlığını kontrol et
critical_files = [
    f"{base_path}/core/orchestrator_hf.py",
    f"{base_path}/llm/model_loader.py",
    f"{base_path}/llm/stage1_mistral.py",
    f"{base_path}/llm/stage2_llama.py",
]

missing_files = []
for file_path in critical_files:
    if not Path(file_path).exists():
        missing_files.append(file_path)

if missing_files:
    print(f"❌ Kritik dosyalar eksik:")
    for file in missing_files:
        print(f"  - {file}")
    print(f"\nLütfen tüm proje dosyalarını yüklediğinizden emin olun.")
    print(f"Beklenen konum: {base_path}")
    raise FileNotFoundError(f"Kritik dosyalar eksik: {len(missing_files)} dosya")

# Path'i sys.path'e ekle
# Önce parent directory'yi ekle (fin_neurosim'in parent'ı)
parent_path = str(base_path_obj.parent)
if parent_path not in sys.path:
    sys.path.insert(0, parent_path)
    print(f"✅ Parent path eklendi: {parent_path}")

# Base path'i de ekle (güvenlik için)
if base_path not in sys.path:
    sys.path.insert(0, base_path)
    print(f"✅ Base path eklendi: {base_path}")

# Projeyi içe aktar
try:
    from fin_neurosim.core.orchestrator_hf import FinNeuroSimOrchestratorHF
    print("✅ Fin-NeuroSim 2.0 başarıyla yüklendi")
except ImportError as e:
    print(f"❌ Import hatası: {e}")
    print(f"\n🔍 Debug bilgileri:")
    print(f"  Base path var mı: {base_path_obj.exists()}")
    print(f"  Parent path: {parent_path}")
    print(f"  sys.path içeriği:")
    for i, p in enumerate(sys.path[:5], 1):
        print(f"    {i}. {p}")

    # Dosya yapısını kontrol et
    print(f"\n📁 Klasör içeriği ({base_path}):")
    if base_path_obj.exists():
        try:
            items = list(base_path_obj.iterdir())
            for item in items[:10]:
                print(f"  - {item.name} ({'klasör' if item.is_dir() else 'dosya'})")
        except Exception as e:
            print(f"  Klasör okunamadı: {e}")

    print(f"\n💡 Çözüm önerileri:")
    print(f"1. Proje dosyalarının tamamını yüklediğinizden emin olun")
    print(f"2. Klasör yapısının doğru olduğunu kontrol edin")
    print(f"3. Tüm Python dosyalarının (.py) yüklendiğini kontrol edin")
    raise

# Async fonksiyon
async def run_analysis():
    """Risk analizi çalıştırır."""
    try:
        print("\n🚀 Orchestrator başlatılıyor...")
        orchestrator = FinNeuroSimOrchestratorHF()

        # Kullanıcıdan sorgu al
        print("\n" + "="*60)
        print("📝 SORGU GİRİŞİ")
        print("="*60)
        default_query = "TSLA hissesi için risk analizi yap"
        user_input = input(f"\nLütfen sorgunuzu girin (Enter'a basarsanız varsayılan kullanılır):\nÖrnek: {default_query}\n\nSorgu: ").strip()

        if not user_input:
            user_input = default_query
            print(f"✅ Varsayılan sorgu kullanılıyor: {user_input}")
        else:
            print(f"✅ Sorgu alındı: {user_input}")

        print("\n📊 Analiz başlatılıyor...")
        result = await orchestrator.process_query(user_input)

        return result
    except Exception as e:
        print(f"❌ Hata: {e}")
        import traceback
        traceback.print_exc()
        raise

def print_detailed_report(result):
    """
    Detaylı raporu formatlanmış şekilde yazdırır.

    Args:
        result: FinalReport nesnesi.
    """
    from datetime import datetime
    import textwrap

    # Başlık
    print("\n" + "="*100)
    print(" " * 30 + "📊 FIN-NEUROSIM 2.0 - RİSK ANALİZİ RAPORU")
    print("="*100)

    # Tarih ve saat
    timestamp = result.timestamp if hasattr(result, 'timestamp') else datetime.now()
    if isinstance(timestamp, str):
        try:
            timestamp = datetime.fromisoformat(timestamp.replace('Z', '+00:00'))
        except:
            pass

    print(f"\n📅 Rapor Tarihi: {timestamp.strftime('%Y-%m-%d %H:%M:%S') if isinstance(timestamp, datetime) else timestamp}")
    print(f"🔍 Analiz Sorgusu: {result.query}")
    print("\n" + "-"*100)

    # Risk Özeti
    print("\n" + " " * 35 + "🎯 RİSK ÖZETİ")
    print("-"*100)

    risk_level = result.final_risk_level.upper()
    risk_emoji = {
        "CRITICAL": "🔴",
        "HIGH": "🟠",
        "MEDIUM": "🟡",
        "LOW": "🟢"
    }.get(risk_level, "⚪")

    print(f"\n{risk_emoji} Risk Seviyesi: {risk_level}")
    print(f"📊 Güven Skoru: {result.overall_confidence:.1%}")
    print(f"📈 Veri Tazeliği: {result.data_freshness_score:.1%}")

    # Stratejik Gerekçe (Tam - Kesilmeden)
    print("\n" + " " * 30 + "📝 STRATEJİK GEREKÇE VE ANALİZ")
    print("-"*100)

    # Metni paragraflara böl ve formatla
    rationale = result.strategic_rationale
    if rationale:
        # Paragrafları ayır
        paragraphs = rationale.split('\n\n')
        for para in paragraphs:
            if para.strip():
                # Her satırı 90 karaktere sığdır
                wrapped = textwrap.fill(para.strip(), width=90, initial_indent="   ", subsequent_indent="   ")
                print(f"\n{wrapped}")
    else:
        print("\n   ⚠️  Stratejik gerekçe bulunamadı.")

    # Aksiyon Planı (Tam - Tüm aksiyonlar)
    print("\n" + " " * 35 + "🎯 AKSİYON PLANI")
    print("-"*100)

    if result.action_plan and len(result.action_plan) > 0:
        priority_emoji = {
            "immediate": "🔴",
            "high": "🟠",
            "medium": "🟡",
            "low": "🟢"
        }

        for i, action in enumerate(result.action_plan, 1):
            priority = action.priority.lower()
            emoji = priority_emoji.get(priority, "⚪")

            print(f"\n{emoji} Aksiyon {i}: [{action.priority.upper()}]")
            print(f"   📌 {action.action}")
            if action.rationale and action.rationale.strip():
                rationale_wrapped = textwrap.fill(
                    action.rationale.strip(),
                    width=85,
                    initial_indent="   💡 Gerekçe: ",
                    subsequent_indent="              "
                )
                print(f"   {rationale_wrapped}")
    else:
        print("\n   ⚠️  Aksiyon planı bulunamadı veya boş.")
        print("   💡 LLM'den aksiyon planı üretilemedi. Bu durumda manuel değerlendirme önerilir.")

    # Ajan Katkıları
    print("\n" + " " * 32 + "🤖 AJAN KATKILARI VE ANALİZLER")
    print("-"*100)

    if result.agent_contributions and len(result.agent_contributions) > 0:
        for agent in result.agent_contributions:
            agent_name = agent.agent_id
            risk_level_agent = agent.risk_level.upper()
            confidence_agent = agent.confidence

            print(f"\n📊 {agent_name}:")
            print(f"   Risk Seviyesi: {risk_level_agent}")
            print(f"   Güven Skoru: {confidence_agent:.1%}")

            if agent.key_drivers and len(agent.key_drivers) > 0:
                print(f"   Ana Faktörler:")
                for driver in agent.key_drivers[:8]:  # İlk 8 faktör
                    print(f"      • {driver}")

            if agent.reasoning and len(agent.reasoning) > 0:
                # Reasoning'i kısalt ama tamamen gösterme
                reasoning_short = agent.reasoning[:500] + "..." if len(agent.reasoning) > 300 else agent.reasoning
                reasoning_wrapped = textwrap.fill(
                    reasoning_short,
                    width=85,
                    initial_indent="   Özet: ",
                    subsequent_indent="          "
                )
                print(f"   {reasoning_wrapped}")
    else:
        print("\n   ⚠️  Ajan katkıları bulunamadı.")

    # Uyarılar
    if result.warnings and len(result.warnings) > 0:
        print("\n" + " " * 38 + "⚠️  UYARILAR VE SINIRLAMALAR")
        print("-"*100)
        for warning in result.warnings:
            warning_wrapped = textwrap.fill(
                warning,
                width=90,
                initial_indent="   ⚠️  ",
                subsequent_indent="       "
            )
            print(f"   {warning_wrapped}")

    # Metadata (varsa)
    if hasattr(result, 'metadata') and result.metadata:
        print("\n" + " " * 35 + "📋 EK BİLGİLER")
        print("-"*100)
        for key, value in result.metadata.items():
            print(f"   {key}: {value}")

    # Alt bilgi
    print("\n" + "="*100)
    print(" " * 25 + "Fin-NeuroSim 2.0 - Web-Native Financial Intelligence System")
    print("="*100 + "\n")


# Çalıştır
if __name__ == "__main__":

    result = asyncio.run(run_analysis())

    # Detaylı raporu göster
    print_detailed_report(result)
# Out:
# CUDA Mevcut: True
# GPU: Tesla T4
# VRAM: 14.74 GB
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# 🔍 Proje yapısı kontrol ediliyor...
# ✅ /content/drive/MyDrive/LLM_Proje/fin_neurosim/core
# ✅ /content/drive/MyDrive/LLM_Proje/fin_neurosim/llm
# ✅ /content/drive/MyDrive/LLM_Proje/fin_neurosim/agents
# ✅ /content/drive/MyDrive/LLM_Proje/fin_neurosim/data_sources
# ✅ /content/drive/MyDrive/LLM_Proje/fin_neurosim/prompts
# ✅ /content/drive/MyDrive/LLM_Proje/fin_neurosim/schemas
# ✅ /content/drive/MyDrive/LLM_Proje/fin_neurosim/utils
# ✅ /content/drive/MyDrive/LLM_Proje/fin_neurosim/mvp
# ...
